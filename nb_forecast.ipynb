# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from surveys import BAOBin, GetSurvey
from bao_forecast import CombinedBAOError

# ---------------------------------------------------------
# Data setup
# ---------------------------------------------------------

survey = "DES_Y6"
survey = "LSST_Y10"
bins, area = GetSurvey(survey)

# ---------------------------------------------------------
# Forecast
# ---------------------------------------------------------

forecast = CombinedBAOError(
    bins=bins,
    area=area,
)

print(f"{forecast * 100:.3f}%")
# Out:
# z=0.250 | Drms=5.1060e-02, Hrms=5.1077e-01, Rrms=4.5892e-02, r=0.3558 | Fisher=4.5892e-02
# z=0.350 | Drms=3.6109e-02, Hrms=3.5928e-01, Rrms=3.2457e-02, r=0.3552 | Fisher=3.2457e-02
# z=0.450 | Drms=2.7871e-02, Hrms=2.7362e-01, Rrms=2.5052e-02, r=0.3541 | Fisher=2.5052e-02
# z=0.550 | Drms=2.2708e-02, Hrms=2.1878e-01, Rrms=2.0406e-02, r=0.3530 | Fisher=2.0406e-02
# z=0.650 | Drms=1.9214e-02, Hrms=1.8138e-01, Rrms=1.7254e-02, r=0.3526 | Fisher=1.7254e-02
# z=0.750 | Drms=1.6719e-02, Hrms=1.5450e-01, Rrms=1.4996e-02, r=0.3531 | Fisher=1.4996e-02
# z=0.850 | Drms=1.4866e-02, Hrms=1.3419e-01, Rrms=1.3315e-02, r=0.3536 | Fisher=1.3315e-02
# z=0.950 | Drms=1.3448e-02, Hrms=1.1832e-01, Rrms=1.2030e-02, r=0.3538 | Fisher=1.2030e-02
# z=1.050 | Drms=1.2344e-02, Hrms=1.0573e-01, Rrms=1.1026e-02, r=0.3539 | Fisher=1.1026e-02
# z=1.150 | Drms=1.1472e-02, Hrms=9.5661e-02, Rrms=1.0233e-02, r=0.3540 | Fisher=1.0233e-02
# 0.535%
